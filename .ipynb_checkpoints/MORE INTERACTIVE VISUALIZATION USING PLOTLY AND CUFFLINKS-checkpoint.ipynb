# %%
import pandas as pd
import numpy as np
from plotly import __version__
print(__version__)
# Out:
# 4.14.3

# %%
import cufflinks as cf
# %matplotlib inline

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # DATA

# %%
df1 = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df1.head()
# Out:
#           A         B         C         D
# 0  0.117187 -1.378889 -0.001494 -1.923561
# 1 -1.383956 -1.296939 -3.104392 -0.822147
# 2  1.258354  0.825089 -0.199466 -0.302414
# 3  0.514698  1.624581 -2.309665  0.444822
# 4 -0.334579  0.047332 -0.964518  0.348910

# %%
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# # USING CUFFLINKS AND iplot()

# %%
df1.iplot() #MORE INTERACTIVE
# Out:
# <div>                            <div id="023d2c65-bf26-4eb2-a335-97a5b7b78c1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Scatter iplot

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# <div>                            <div id="541f232d-ea56-4563-9378-70c1f59c5a3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Bar plots

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="d1137008-e13d-40b9-a0c5-968ae15f4874" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.sum().iplot(kind='bar')  # USING WITH AGGREGATE FUNCTION
# Out:
# <div>                            <div id="df0d7670-db34-4e12-a28f-5497e71d7f22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Box Plots

# %%
df1.iplot(kind='box') # any column values can be turned on or off using just a single click
# Out:
# <div>                            <div id="960d342a-8155-45b2-ba20-47da702596d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # 3d surfaces

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="3d179bdb-3637-4950-ad7f-95dd3962d119" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Histograms

# %%
df1['A'].iplot(kind='hist',bins=25)
# Out:
# <div>                            <div id="ee7ebdfa-ba33-41d1-947f-a7e9f1262cc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='hist',bins=25) #overlapped can be turned on and off
# Out:
# <div>                            <div id="ab0cd9d6-2d27-4f4d-9105-12d0fb27b547" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Spread for financial stocks data

# %%
df1[['A','B']].iplot(kind='spread')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="d0dec031-8f75-4c58-bb7f-ed6f706c9ca6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Bubble Plot usage: similar to scatter but size is based on another column value eg: happiness factor, UN reports

# %%
df1.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="91805e63-616d-4129-ae35-34cc5f1eec41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Scatter Matrix plot all numeric values should be there

# %%
df1.scatter_matrix() # SOMEWHAT SIMILAR TO PAIR PLOT
# Out:
# <div>                            <div id="ef608dc3-0408-4ebc-8b3b-7056ed784122" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
